# %% [markdown]
# # Getting Started

# %%
import pandas as pd
import json
import random
import hashlib
import time
import sys
import os
import logging
from datetime import datetime
from confluent_kafka import Producer

# %% [markdown]
# # Build a catalog of products

# %%
df = pd.read_csv("usercode/TV_DATASET_USA.csv")

# %%
df['BRAND'].value_counts()
# Out:
# SAMSUNG        182
# LG             122
# SONY            88
# TCL             37
# INSIGNIA™       34
# VIZIO           24
# HISENSE         20
# ROKU            19
# TOSHIBA         13
# AMAZON           9
# PEERLESS-AV      4
# PIONEER          3
# FURRION          1
# SHARP            1
# Name: BRAND, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557 entries, 0 to 556
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PRODUCT_NAME  557 non-null    object
#  1   PRICING       557 non-null    object
#  2   URL           557 non-null    object
#  3   BRAND         557 non-null    object
#  4   SCREEN_SIZE   557 non-null    int64
#  5   DISPLAY_TYPE  557 non-null    object
#  6   RESOLUTION    557 non-null    object
#  7   OS            557 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 34.9+ KB

# %%
df['PRICING'] = df['PRICING'].apply(lambda x : float(x.replace('$','').replace(',','')))

# %% [markdown]
# # Set Up Variables and Functions

# %%
cities = ['New York','Los Ángeles','Chicago','Houston','Philadelphia']

payment_modes = ['Credit_card','Stripe','Paypal','Apple_Pay','Google_Pay','Samsung_Pay']

payment_store = ['Cash','Credit_card']

sources = ['Facebook','Instagram','Organic','Twitter','Influencer_1','Influencer_2','Influencer_3','Influencer_4']

purchase_statuses = ['COMPLETED','FAILED_CHECKOUT','FAILED_API_RESPONSE','INSUFICCIENT_FUNDS','COMPLETED','COMPLETED','COMPLETED','COMPLETED','COMPLETED','COMPLETED','FAILED_API_RESPONSE','INSUFICCIENT_FUNDS','USER_ERROR','FRAUD','COMPLETED','COMPLETED','COMPLETED']

commission = [0.2,0.25,0.3,0.27,0.35,0.4,0.37,0.15,0.1]

NY_coords = [(40.76046814557239, -73.97764793953105),(40.76921169592604, -73.98326984936075),(40.762515994719834, -73.98095242088134)]
LA_coords = [(34.07210945806006, -118.35747350374957),(34.071754649810025, -118.37593530089991)]
CHI_coords = [(41.89819876058171, -87.62280110486684),(41.89182575694393, -87.6249468719774),(41.88375296758592, -87.62814652743663)]
HOU_coords = [(29.742233338438325, -95.44654054545151),(29.743148850926094, -95.45312636612748),(29.739981565214627, -95.46428435510245)]
PHI_coords = [(40.089499621312456, -75.39015007888118),(40.085310197975055, -75.40444450974655),(40.09069475292698, -75.3815277170056)]

def get_pay_method(sources,purchase_statuses,payment_modes,payment_store):
    if sources == 'Organic':
        payment = random.choice(payment_store)
        status = 'COMPLETED'
        order_type = 'STORE'
    elif sources != 'Organic':
        payment = random.choice(payment_modes)
        status = random.choice(purchase_statuses)
        order_type = 'ONLINE'
    return payment,status,order_type

def get_coords(city):
    if city == 'New York':
        coords = random.choice(NY_coords)
    elif city == 'Los Ángeles':
        coords = random.choice(LA_coords)
    elif city == 'Chicago':
        coords = random.choice(CHI_coords)
    elif city == 'Houston':
        coords = random.choice(HOU_coords)
    elif city == 'Philadelphia':
        coords = random.choice(PHI_coords)
    return coords

# %% [markdown]
# #  Generate Records

# %%
delivered_records = 0

x = 1

data_purchase = []

while(x < 10):

    date = pd.to_datetime('today').strftime("%Y-%m-%d %H:%M:%S")
    product = df['PRODUCT_NAME'][random.randint(0,556)]
    pricing =  df[df['PRODUCT_NAME']==product]['PRICING'].values[0]
    commission_temp =  random.choice(commission)
    brand = df[df['PRODUCT_NAME']==product]['BRAND'].values[0]
    screen = df[df['PRODUCT_NAME']==product]['SCREEN_SIZE'].values[0]
    display = df[df['PRODUCT_NAME']==product]['DISPLAY_TYPE'].values[0]
    resolution = df[df['PRODUCT_NAME']==product]['DISPLAY_TYPE'].values[0]
    source_temp = random.choice(sources)
    pay = get_pay_method(source_temp,purchase_statuses,payment_modes,payment_store)
    city = random.choice(cities)

    purchase = {'purchase_ID': str(hashlib.sha256(f"{x} {product} {pricing} {commission_temp} {date} {source_temp} {pay[1]}".encode('utf-8')).hexdigest())[:10],
            'Product_name' : product,
            'Pricing':str(pricing),
            'Commission':str(commission_temp),
            'Revenue' : str(round(pricing*commission_temp,2)),
            'Payment_Mehtod':pay[0],
            'Status' : pay[1],
            'Order_Type' : pay[2],
            'City':city,
            'Location': str(get_coords(city)),
            'Latitud' : str(get_coords(city)[0]) ,
            'Longitud' :  str(get_coords(city)[1]),
            'Source':source_temp,
            'Brand' : brand,
            'Screen' : screen,
            'Display' :  display ,
            'Resolution' : resolution,
            'Created_at': date}

    data_purchase.append(pd.DataFrame(purchase,index =[x]))
    delivered_records += 1
    x += 1
    print(purchase)
    time.sleep(random.choice([1,1.5]))

print('\n')
print("{} messages were produced".format(delivered_records))
print('\n')
# Out:
# {'purchase_ID': '30dce4106d', 'Product_name': 'Package - Samsung - 85" Class CU8000 Crystal UHD Smart Tizen TV - Black and SAMSUNG C Series 2.1ch DTS Virtual: X Soundbar - Titan Black', 'Pricing': '1749.98', 'Commission': '0.35', 'Revenue': '612.49', 'Payment_Mehtod': 'Credit_card', 'Status': 'COMPLETED', 'Order_Type': 'ONLINE', 'City': 'Los Ángeles', 'Location': '(34.071754649810025, -118.37593530089991)', 'Latitud': '34.07210945806006', 'Longitud': '-118.35747350374957', 'Source': 'Influencer_1', 'Brand': 'SAMSUNG', 'Screen': 85, 'Display': 'LED', 'Resolution': 'LED', 'Created_at': '2026-01-17 15:09:41'}
# {'purchase_ID': '5762d7a60e', 'Product_name': 'Sony - 85" Class BRAVIA XR Z9J LED 8K UHD Smart Google TV', 'Pricing': '5999.99', 'Commission': '0.25', 'Revenue': '1500.0', 'Payment_Mehtod': 'Samsung_Pay', 'Status': 'COMPLETED', 'Order_Type': 'ONLINE', 'City': 'Los Ángeles', 'Location': '(34.071754649810025, -118.37593530089991)', 'Latitud': '34.07210945806006', 'Longitud': '-118.35747350374957', 'Source': 'Facebook', 'Brand': 'SONY', 'Screen': 85, 'Display': 'XR', 'Resolution': 'XR', 'Created_at': '2026-01-17 15:09:42'}
# {'purchase_ID': '292a6c9b2b', 'Product_name': 'Package - Samsung - The Terrace Series 65" Class LED Outdoor Full Sun 4K QLED Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black', 'Pricing': '8299.98', 'Commission': '0.27', 'Revenue': '2240.99', 'Payment_Mehtod': 'Credit_card', 'Status': 'INSUFICCIENT_FUNDS', 'Order_Type': 'ONLINE', 'City': 'Chicago', 'Location': '(41.89182575694393, -87.6249468719774)', 'Latitud': '41.89182575694393', 'Longitud': '-87.62814652743663', 'Source': 'Instagram', 'Brand': 'SAMSUNG', 'Screen': 65, 'Display': 'LED', 'Resolution': 'LED', 'Created_at': '2026-01-17 15:09:43'}
# {'purchase_ID': 'c5321d2b53', 'Product_name': 'Package - Samsung - 65" Class S90C OLED Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black', 'Pricing': '2999.98', 'Commission': '0.2', 'Revenue': '600.0', 'Payment_Mehtod': 'Apple_Pay', 'Status': 'COMPLETED', 'Order_Type': 'ONLINE', 'City': 'Philadelphia', 'Location': '(40.089499621312456, -75.39015007888118)', 'Latitud': '40.089499621312456', 'Longitud': '-75.40444450974655', 'Source': 'Influencer_2', 'Brand': 'SAMSUNG', 'Screen': 65, 'Display': 'LED', 'Resolution': 'LED', 'Created_at': '2026-01-17 15:09:45'}
# {'purchase_ID': '39bd602f7a', 'Product_name': 'Sony - 75" Class BRAVIA XR Z9K 8K HDR Mini LED Google TV', 'Pricing': '5499.99', 'Commission': '0.25', 'Revenue': '1375.0', 'Payment_Mehtod': 'Samsung_Pay', 'Status': 'COMPLETED', 'Order_Type': 'ONLINE', 'City': 'Philadelphia', 'Location': '(40.089499621312456, -75.39015007888118)', 'Latitud': '40.09069475292698', 'Longitud': '-75.3815277170056', 'Source': 'Influencer_3', 'Brand': 'SONY', 'Screen': 75, 'Display': 'XR', 'Resolution': 'XR', 'Created_at': '2026-01-17 15:09:46'}
# {'purchase_ID': '1fe92639d8', 'Product_name': 'Furrion - 50" Partial Sun 4K UHD Smart Outdoor TV', 'Pricing': '1399.99', 'Commission': '0.3', 'Revenue': '420.0', 'Payment_Mehtod': 'Paypal', 'Status': 'FAILED_API_RESPONSE', 'Order_Type': 'ONLINE', 'City': 'Los Ángeles', 'Location': '(34.071754649810025, -118.37593530089991)', 'Latitud': '34.071754649810025', 'Longitud': '-118.37593530089991', 'Source': 'Influencer_1', 'Brand': 'FURRION', 'Screen': 50, 'Display': '4K', 'Resolution': '4K', 'Created_at': '2026-01-17 15:09:47'}
# {'purchase_ID': '58965cadfb', 'Product_name': 'Sony - 65" Class A8H Series OLED 4K UHD Smart Android TV', 'Pricing': '1374.99', 'Commission': '0.3', 'Revenue': '412.5', 'Payment_Mehtod': 'Paypal', 'Status': 'COMPLETED', 'Order_Type': 'ONLINE', 'City': 'Houston', 'Location': '(29.742233338438325, -95.44654054545151)', 'Latitud': '29.739981565214627', 'Longitud': '-95.45312636612748', 'Source': 'Influencer_1', 'Brand': 'SONY', 'Screen': 65, 'Display': 'OLED', 'Resolution': 'OLED', 'Created_at': '2026-01-17 15:09:48'}
# {'purchase_ID': 'cfe2c9f996', 'Product_name': 'Samsung - 65" Class Q80B QLED 4K Smart Tizen TV', 'Pricing': '999.99', 'Commission': '0.4', 'Revenue': '400.0', 'Payment_Mehtod': 'Credit_card', 'Status': 'USER_ERROR', 'Order_Type': 'ONLINE', 'City': 'Philadelphia', 'Location': '(40.085310197975055, -75.40444450974655)', 'Latitud': '40.09069475292698', 'Longitud': '-75.3815277170056', 'Source': 'Influencer_1', 'Brand': 'SAMSUNG', 'Screen': 65, 'Display': 'QLED', 'Resolution': 'QLED', 'Created_at': '2026-01-17 15:09:50'}
# {'purchase_ID': 'dcbf5a0d54', 'Product_name': 'LG - 77" Class C3 Series OLED 4K UHD Smart webOS TV', 'Pricing': '3199.99', 'Commission': '0.27', 'Revenue': '864.0', 'Payment_Mehtod': 'Samsung_Pay', 'Status': 'FAILED_API_RESPONSE', 'Order_Type': 'ONLINE', 'City': 'Philadelphia', 'Location': '(40.09069475292698, -75.3815277170056)', 'Latitud': '40.085310197975055', 'Longitud': '-75.39015007888118', 'Source': 'Influencer_1', 'Brand': 'LG', 'Screen': 77, 'Display': 'OLED', 'Resolution': 'OLED', 'Created_at': '2026-01-17 15:09:52'}
#
#
# 9 messages were produced

# %% [markdown]
# #  Create a Kafka Producer Instance

# %%
from confluent_kafka import Producer

conf = {
    'bootstrap.servers': '$BOOTSTRAP_SERVERS',
    'security.protocol': 'SASL_SSL',
    'sasl.mechanisms': 'PLAIN',
    'sasl.username': '$SASL_USERNAME',
    'sasl.password': '$SASL_PASSWORD'   
}


producer = Producer(conf)
print("Producteur Kafka créé avec succès !")
# Out:
# Producteur Kafka créé avec succès !

# %% [markdown]
# #  Send Records to Kafka Topic

# %%
delivered_records = 0
topic = 'ecommerce-topic-1' 
x = 1

while True:
    # Génération de la date actuelle
    date = pd.to_datetime('today').strftime("%Y-%m-%d %H:%M:%S")
    
    # Sélection aléatoire d'un produit et de ses caractéristiques
    idx = random.randint(0, 556)
    product = df['PRODUCT_NAME'].iloc[idx]
    pricing = df[df['PRODUCT_NAME'] == product]['PRICING'].values[0]
    brand = df[df['PRODUCT_NAME'] == product]['BRAND'].values[0]
    screen = df[df['PRODUCT_NAME'] == product]['SCREEN_SIZE'].values[0]
    display = df[df['PRODUCT_NAME'] == product]['DISPLAY_TYPE'].values[0]
    resolution = df[df['PRODUCT_NAME'] == product]['DISPLAY_TYPE'].values[0]
    
    # Sélection des variables aléatoires
    commission_temp = random.choice(commission)
    source_temp = random.choice(sources)
    pay = get_pay_method(source_temp, purchase_statuses, payment_modes, payment_store)
    city = random.choice(cities)

    # Création du dictionnaire avec clés en MINUSCULES
    purchase = {
        'purchase_id': str(hashlib.sha256(f"{x} {product} {pricing} {date}".encode('utf-8')).hexdigest())[:10],
        'product_name': product,
        'pricing': str(int(pricing)),
        'commission': str(commission_temp),
        'revenue': str(round(pricing * commission_temp, 2)),
        'payment_method': pay[0],
        'status': pay[1],
        'order_type': pay[2],
        'city': city,
        'location': str(get_coords(city)),
        'latitude': str(get_coords(city)[0]),
        'longitude': str(get_coords(city)[1]),
        'source': source_temp,
        'brand': brand,
        'screen_size': str(screen),
        'display_type': display,
        'resolution': str(resolution),
        'created_at': date
    }

    # Encodage et envoi vers Kafka
    record_key = "Purchase_simulator"
    record_value = json.dumps(purchase).encode('utf-8')
    
    producer.produce(topic, key=record_key, value=record_value)
    producer.poll(0)
    
    print(f"Envoi réussi : {purchase['product_name']} | Status : {purchase['status']}")
    
    delivered_records += 1
    x += 1
    
    # Pause et Flush pour assurer l'envoi
    time.sleep(random.choice([1, 1.5]))
    producer.flush()
# Out:
# Envoi réussi : TCL - 50" Class 5-Series QLED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 85" Class QN90C NEO QLED 4K Smart TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : VIZIO - 24" Class D-Series LED 720P Smart TV | Status : FAILED_CHECKOUT
# Envoi réussi : Samsung - 43" QMB series LED 4K UHD Digital Signage Display - Black | Status : FAILED_API_RESPONSE
# Envoi réussi : Samsung - 85" Class QN900A Series Neo QLED 8K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - 55" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Hisense - 43" Class R6G Series LED 4K UHD Smart Roku TV | Status : USER_ERROR
# Envoi réussi : Samsung - 85" Class QN800 Neo QLED 8K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Samsung - 85" Class  Q70A Series QLED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - 86" Class 99 Series QNED Mini-LED 8K UHD Smart webOS TV | Status : FAILED_CHECKOUT
# Envoi réussi : Sharp - 65" Class LED 4K Smart Roku TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 55" Class F50 Series QLED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Samsung - 82" Class Q60T Series  LED 4K UHD Smart Tizen TV | Status : FAILED_CHECKOUT
# Envoi réussi : LG - 77" Class C3 Series OLED 4K UHD Smart webOS TV | Status : FAILED_CHECKOUT
# Envoi réussi : Insignia™ - 70" Class F50 Series QLED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Samsung - 43" Class The Sero Series LED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : VIZIO - 40" Class D-Series LED 1080P Smart TV | Status : USER_ERROR
# Envoi réussi : Roku - 65" Class Select Series 4K Smart RokuTV | Status : COMPLETED
# Envoi réussi : Sony - 65" Class BRAVIA XR A95K 4K HDR OLED Google TV | Status : COMPLETED
# Envoi réussi : Package - Hisense - 75" Class U6H Series Quantum ULED 4K UHD Smart Google TV and 2.1-Channel Soundbar with Built-in Subwoofer - black | Status : FRAUD
# Envoi réussi : Package - Roku - 43" Class Select Series 4K Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - The Terrace Series 75" Class LED Outdoor Full Sun 4K QLED Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : FAILED_CHECKOUT
# Envoi réussi : Samsung - 43" Class Q60C QLED 4K Smart Tizen TV | Status : FRAUD
# Envoi réussi : LG - 97" Class G2 Series OLED evo 4K UHD Smart webOS TV with Gallery Design | Status : COMPLETED
# Envoi réussi : Package - Roku - 75" Class Plus Series QLED 4K Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : COMPLETED
# Envoi réussi : Samsung - 110" Class Micro LED 4K Smart Tizen TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Samsung - 65" Class The Frame QLED 4k Smart Tizen TV - Charcoal Black and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Samsung - 55" Class QN85B Neo QLED 4K Smart Tizen TV | Status : USER_ERROR
# Envoi réussi : Package - Samsung - 55" Class The Frame QLED 4k Smart Tizen TV - Charcoal Black and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - 75" Class QN800C Neo QLED 8K Smart Tizen TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class QN900A Series Neo QLED 8K UHD Smart Tizen TV | Status : FAILED_API_RESPONSE
# Envoi réussi : VIZIO - 43" Class V-Series 4K LED HDR Smart TV | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class 8000 Series LED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Samsung - 55" Class QN700B Neo QLED 8K Smart TV | Status : COMPLETED
# Envoi réussi : TCL - 43" Class 3-Series Full HD Smart Android TV | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class QN800 Neo QLED 8K UHD Smart Tizen TV | Status : FAILED_CHECKOUT
# Envoi réussi : LG - StanbyME 27" Class LED Full HD Smart webOS Touch Screen | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class S90C OLED Smart Tizen TV | Status : COMPLETED
# Envoi réussi : VIZIO - 40" Class D-Series LED 1080P Smart TV | Status : COMPLETED
# Envoi réussi : LG - 75" Class 99 Series QNED Mini-LED 8K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 50" Class F50 Series QLED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Amazon - 55" Class 4-Series 4K UHD Smart Fire TV | Status : FRAUD
# Envoi réussi : Sony - 65" class BRAVIA XR X90L Full Array LED 4K HDR Google TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 75" Class CU8000 Crystal UHD Smart Tizen TV - Black and SAMSUNG C Series 2.1ch DTS Virtual: X Soundbar - Titan Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - 55" Class QN90C NEO QLED 4K Smart TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : FAILED_API_RESPONSE
# Envoi réussi : Insignia™ - 43" Class N10 Series LED Full HD TV | Status : COMPLETED
# Envoi réussi : VIZIO - 32" Class D-Series Full HD Smart TV | Status : COMPLETED
# Envoi réussi : TCL - 32" Class 3-Series Full HD LED Smart Roku TV | Status : FRAUD
# Envoi réussi : LG - 55" Class 75 Series QNED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - The Terrace Series 75" Class LED Outdoor Full Sun 4K QLED Smart Tizen TV and 3.0-Channel The Terrace Soundbar with Dolby Digital 5.1 - Titan Black | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - Samsung - 85" Class QN85C NEO QLED 4K Smart Tizen TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : USER_ERROR
# Envoi réussi : LG - 83" Class G3 Series OLED 4K UHD Smart webOS TV with One Wall Design | Status : COMPLETED
# Envoi réussi : LG - 50" Class 80 Series QNED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 86" Class 90 Series QNED Mini-LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 55" Class BRAVIA XR A90J Series OLED 4K UHD Smart Google TV and Ultra Slim Wall Mount for Select SONY TVs - Black | Status : COMPLETED
# Envoi réussi : Roku - 75" Class Plus Series QLED 4K Smart RokuTV | Status : COMPLETED
# Envoi réussi : LG - 55" Class 85 Series QNED Mini-LED 4K UHD Smart webOS TV | Status : FAILED_API_RESPONSE
# Envoi réussi : LG - 48" Class C2 Series OLED evo 4K  UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Samsung - 98" Class Neo QLED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - 75" Class 80 Series QNED 4K UHD Smart webOS TV | Status : USER_ERROR
# Envoi réussi : Samsung - 55" Class S90C OLED Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Samsung - 50" Class QN90B Neo QLED 4K Smart Tizen TV | Status : FAILED_API_RESPONSE
# Envoi réussi : LG - 50" Class 80 Series QNED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Toshiba - 32" Class V35 Series LED HD Smart Fire TV | Status : FRAUD
# Envoi réussi : Package - Sony - 55" Class BRAVIA XR A80J Series OLED 4K UHD Smart Google TV and Ultra Slim Wall Mount for Select SONY TVs - Black | Status : COMPLETED
# Envoi réussi : Samsung - 55" Class QN700B Neo QLED 8K Smart TV | Status : FRAUD
# Envoi réussi : Toshiba - 55" Class M550 Series LED 4K UHD Smart Fire TV with hands-free Alexa | Status : COMPLETED
# Envoi réussi : Package - Insignia™ - 32" Class N10 Series LED HD TV - Black and Google - Chromecast with Google TV (HD) - Snow | Status : COMPLETED
# Envoi réussi : Package - Sony - 48" Class BRAVIA A9S Series OLED 4K UHD Smart Android TV and Ultra Slim Wall Mount for Select SONY TVs - Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - 55" Class Q80C QLED 4K Smart Tizen TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Roku - 55" Class Plus Series QLED 4K Smart RokuTV | Status : COMPLETED
# Envoi réussi : LG - 43" Class UR9000 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 65" Class The Serif QLED 4K Smart TV - White and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : FAILED_CHECKOUT
# Envoi réussi : Hisense - 40" Class A4G Series LED  Full HD Smart Vidaa TV | Status : COMPLETED
# Envoi réussi : LG - 77" Class G2 Series OLED evo 4K UHD Smart webOS TV with Gallery Design | Status : COMPLETED
# Envoi réussi : LG - 50" Class UQ75 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 50" Class UQ75 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 77" Class A2 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class Q70C QLED 4K SMART TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 24" Class F20 Series LED HD Smart Fire TV | Status : COMPLETED
# Envoi réussi : LG - StanbyME 27" Class LED Full HD Smart webOS Touch Screen | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Sony - 50" Class X85K 4K HDR LED Google TV | Status : FAILED_API_RESPONSE
# Envoi réussi : LG - 55" Class B2 Series OLED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : TCL - 55" Class 4-Series 4K UHD HDR Smart Roku TV | Status : FRAUD
# Envoi réussi : LG - 48" Class A2 Series OLED 4K UHD Smart webOS TV | Status : FRAUD
# Envoi réussi : Insignia™ - 39" Class F20 Series LED HD Smart Fire TV Edition TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 55" Class F50 Series QLED 4K UHD Smart Fire TV | Status : USER_ERROR
# Envoi réussi : Sony - 55" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Sony - 75" Class X85K 4K HDR LED Google TV and HTA3000 3.1 ch Dolby Atmos Soundbar - Black | Status : COMPLETED
# Envoi réussi : Hisense - 55" Class A6 Series LED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : LG - 70" Class UQ9000 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Samsung - 55" QMB series LED 4K UHD Digital Signage Display | Status : COMPLETED
# Envoi réussi : Package - Samsung - 75" Class The Frame QLED 4k Smart Tizen TV - Charcoal Black and 3.1.2ch Soundbar with Wireless Dolby Atmos / DTS:X - Black | Status : COMPLETED
# Envoi réussi : Sony - 85" Class X80K Series LED 4K HDR Smart Google TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 65" Class S90C OLED Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - 85" Class Q70C QLED 4K Smart TV - Black and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : LG - 75" Class UP7300PUC LED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Sony - 48" Class BRAVIA XR A90K 4K HDR OLED Google TV | Status : USER_ERROR
# Envoi réussi : Samsung - 32" Class Q60A Series  QLED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 43" Class N10 Series LED Full HD TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : TCL - 70" Class 4-Series LED 4K UHD HDR Smart Android TV | Status : COMPLETED
# Envoi réussi : TCL - 70" Class 4-Series LED 4K UHD HDR Smart Android TV | Status : COMPLETED
# Envoi réussi : Package - LG - 86" Class 90 Series QNED Mini-LED 4K UHD Smart webOS TV - Gray and 5.1 Channel High-Res Audio Soundbar with DTS Virtual:X - Black | Status : COMPLETED
# Envoi réussi : TCL - 43" Class 4-Series 4K UHD HDR Smart Roku TV | Status : FRAUD
# Envoi réussi : Package - Sony - 65" Class BRAVIA XR A80K OLED 4K UHD HDR Google TV and Sony HT-A5000 Dolby Atmos Smart Soundbar works with Alexa and Google Assistant, Chromecast built-in, AirPlay2, Bluetooth - Black | Status : COMPLETED
# Envoi réussi : Amazon - 55" Class Omni Series 4K UHD Smart Fire TV hands-free with Alexa | Status : COMPLETED
# Envoi réussi : Package - LG - 77" Class A2 Series OLED 4K UHD Smart webOS TV and 5.1.2 Channel Soundbar with Wireless Subwoofer, Dolby Atmos and DTS:X - Black | Status : COMPLETED
# Envoi réussi : Samsung - 98" Class Q80C QLED 4K Smart TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Sony - 77" Class BRAVIA XR A80K 4K HDR OLED Google TV | Status : FRAUD
# Envoi réussi : Toshiba - 43" Class C350 Series LED 4K UHD Smart Fire TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Pioneer - 50" Class LED 4K UHD Smart Fire TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Sony - 48" Class BRAVIA A9S Series OLED 4K UHD Smart Android TV and Ultra Slim Wall Mount for Select SONY TVs - Black | Status : COMPLETED
# Envoi réussi : LG - 65" UR640S Series LED 4K UHD Digital Signage TV | Status : USER_ERROR
# Envoi réussi : VIZIO - 50" Class V-Series LED 4K UHD Smart TV | Status : COMPLETED
# Envoi réussi : Hisense - 70" Class A6G Series LED 4K UHD Smart Android TV | Status : USER_ERROR
# Envoi réussi : TCL - 65" Class 6-Series Mini-LED QLED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : Samsung - 55" Class QN700B Neo QLED 8K Smart TV | Status : FRAUD
# Envoi réussi : Samsung - 75" CLASS BE75T-H LED 4K Commercial Grade TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : TCL - 43" Class 4-Series LED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 65" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV and HTA3000 3.1 ch Dolby Atmos Soundbar - Black | Status : FAILED_API_RESPONSE
# Envoi réussi : Sony - 83" Class A90J Series OLED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 55" Class S90C OLED Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : USER_ERROR
# Envoi réussi : TCL - 55" Class 6-Series 4K Mini-LED UHD QLED Dolby Vision HDR Smart Roku TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 85" Class The Frame QLED 4k Smart Tizen TV - Charcoal Black and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : FAILED_API_RESPONSE
# Envoi réussi : Sony - 55" class X77L 4K HDR LED Google TV | Status : COMPLETED
# Envoi réussi : LG - 86" Class NanoCell 90 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : VIZIO - 75" Class M7 Series 4K QLED HDR Smart TV | Status : COMPLETED
# Envoi réussi : TCL - 75" Class 4-Series LED 4K UHD Smart Google TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Insignia™ - 32" Class F20 Series LED Full HD Smart Fire TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Sony - 50" class X77L 4K HDR LED Google TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : TCL - 32" Class 3-Series FHD 1080p LED Smart Google TV | Status : COMPLETED
# Envoi réussi : Package - Roku - 32" Class Select Series HD Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Toshiba - 75" Class M550 Series LED 4K UHD Smart Fire TV with hands-free Alexa | Status : COMPLETED
# Envoi réussi : LG - 75" UR340C Series LED 4K UHD Digital Signage TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : VIZIO - 65" Class MQ6 Series 4K QLED HDR Smart TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Hisense - 70" Class A6 Series LED 4K UHD Smart Google TV | Status : FAILED_CHECKOUT
# Envoi réussi : Package - Sony - 65" Class BRAVIA XR A90J Series OLED 4K UHD Smart Google TV and Ultra Slim Wall Mount for Select SONY TVs - Black | Status : FAILED_API_RESPONSE
# Envoi réussi : Hisense - 40" Class A4G Series LED  Full HD Smart Vidaa TV | Status : COMPLETED
# Envoi réussi : Package - Insignia™ - 43" Class N10 Series LED Full HD TV - Black and Google - Chromecast with Google TV (HD) - Snow | Status : COMPLETED
# Envoi réussi : LG - 65" Class 90 Series QNED Mini-LED 4K UHD Smart webOS TV | Status : USER_ERROR
# Envoi réussi : Package - Samsung - 55" Class S95C OLED 4K Smart Tizen TV and SAMSUNG Q-Series 3.1ch Dolby Atmos Soundbar w/Q-Symphony. - Titan Black | Status : COMPLETED
# Envoi réussi : Insignia™ - 65" Class F30 Series LED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : LG - 75" Class 80 Series QNED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Samsung - 50" Class The Frame QLED 4k Smart Tizen TV - Charcoal Black and 3.1.2ch Soundbar with Wireless Dolby Atmos / DTS:X - Black | Status : COMPLETED
# Envoi réussi : TCL - 58" Class 4-Series 4K UHD HDR Smart Roku TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : LG - 43" Class 75 Series QNED 4K UHD Smart webOS TV | Status : FRAUD
# Envoi réussi : Samsung - 55" Class QN95B Neo QLED 4K Smart TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - Samsung - The Terrace Series 65" Class LED Outdoor Partial Sun 4K UHD Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : TCL - 32" Class 3-Series FHD 1080p LED Smart Google TV | Status : FRAUD
# Envoi réussi : Sony - 65" Class A8H Series OLED 4K UHD Smart Android TV | Status : FAILED_API_RESPONSE
# Envoi réussi : LG - 65" Class 99 Series QNED Mini-LED 8K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - SAMSUNG C Series 2.1ch DTS Virtual: X Soundbar - Titan Black and 75" Class CU7000 Crystal UHD 4K UHD Smart Tizen TV - TITAN GRAY | Status : COMPLETED
# Envoi réussi : LG - 55" Class B3 Series OLED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Samsung - 50" Class The Frame QLED 4k Smart Tizen TV - Charcoal Black and 3.1.2ch Soundbar with Wireless Dolby Atmos / DTS:X - Black | Status : USER_ERROR
# Envoi réussi : LG - 65" Class C1 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 70" Class F30 Series LED 4K UHD Smart Fire TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Samsung - 85" Class The Frame QLED 4k Smart Tizen TV - Charcoal Black and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class TU690T Series LED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class QN800 Neo QLED 8K UHD Smart Tizen TV | Status : USER_ERROR
# Envoi réussi : LG - 50" UR340C Series LED 4K UHD Digital Signage TV | Status : COMPLETED
# Envoi réussi : Package - TCL - 50" Class 5-Series QLED 4K UHD Smart Google TV - Black and eero - Pro 6 Tri-Band Wi-Fi 6 | Status : FAILED_API_RESPONSE
# Envoi réussi : Samsung - 75" Class QN900C Neo QLED 8K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - 77" Class G2 Series OLED evo 4K UHD Smart webOS TV with Gallery Design | Status : FAILED_API_RESPONSE
# Envoi réussi : SAMSUNG 55" Class TU690T Crystal UHD 4K Smart TV powered by Tizen Smart TV | Status : FRAUD
# Envoi réussi : Samsung - 43" Class The Sero Series LED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class QN84A Neo QLED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Samsung - 85" Class QN900C Neo QLED 8K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 42" Class F20 Series LED Full HD Smart Fire TV | Status : USER_ERROR
# Envoi réussi : LG - 77" Class A2 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : TCL - 40" Class 3-Series Full HD 1080p Smart Roku TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : LG - 55" Class UQ75 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 85" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : LG - 65" Class B3 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 70" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : SAMSUNG 55" Class TU690T Crystal UHD 4K Smart TV powered by Tizen Smart TV | Status : FAILED_CHECKOUT
# Envoi réussi : Sony - 55" class X77L 4K HDR LED Google TV | Status : USER_ERROR
# Envoi réussi : VIZIO - 40" Class D-Series Full HD Smart TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Samsung - The Terrace Series 75" Class LED Outdoor Partial Sun 4K UHD Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - 65" Class Q80C QLED 4K Smart Tizen TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : TCL - 75" Class 6-Series 4K Mini-LED UHD QLED Dolby Vision HDR Smart Roku TV | Status : COMPLETED
# Envoi réussi : Samsung - 85" Class QN800C Neo QLED 8K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Toshiba - 50" Class C350 Series LED 4K UHD Smart Fire TV | Status : FRAUD
# Envoi réussi : Package - Sony - 75" class BRAVIA XR X93L Mini LED 4K HDR Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class  Q70A Series QLED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - 75" Class UR9000 Series LED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Samsung - 82" Class Q60T Series  LED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Roku - 75" Class Plus Series QLED 4K Smart RokuTV | Status : COMPLETED
# Envoi réussi : Samsung - 55" Class S95B OLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 65" class BRAVIA XR X93L Mini LED 4K HDR Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Samsung - 65" Class QN95B Neo QLED 4K Smart TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Sony - 85" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV | Status : FAILED_CHECKOUT
# Envoi réussi : Package - Roku - 24" Class Select Series HD Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : COMPLETED
# Envoi réussi : Samsung - 85" Class Q70C QLED 4K Smart TV | Status : COMPLETED
# Envoi réussi : VIZIO - 50" Class V-Series LED 4K UHD Smart TV | Status : FRAUD
# Envoi réussi : LG - 83" Class C1 Series OLED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Sony - 65" class BRAVIA XR X90L Full Array LED 4K HDR Google TV and Sony HT-A5000 Dolby Atmos Smart Soundbar works with Alexa and Google Assistant, Chromecast built-in, AirPlay2, Bluetooth - Black | Status : COMPLETED
# Envoi réussi : Samsung - 43" CLASS BE43T-H LED 4K Commercial Grade TV | Status : FRAUD
# Envoi réussi : LG - 55" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : TCL - 75" Class 5-Series 4K UHD QLED Dolby Vision HDR Smart Roku TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - Samsung - SAMSUNG C Series 2.1ch DTS Virtual: X Soundbar - Titan Black and 75" Class CU7000 Crystal UHD 4K UHD Smart Tizen TV - TITAN GRAY | Status : FRAUD
# Envoi réussi : Samsung - 82" CLASS BE82T-H LED 4K Commercial Grade TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 75" class BRAVIA XR X93L Mini LED 4K HDR Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : Roku - 65" Class Plus Series QLED 4K Smart RokuTV | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class S95B OLED 4K Smart Tizen TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : LG - 86" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 50" Class UR9000 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 65" Class X80K Series LED 4K UHD HDR Smart Google TV and Sony HT-A5000 Dolby Atmos Smart Soundbar works with Alexa and Google Assistant, Chromecast built-in, AirPlay2, Bluetooth - Black | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Sony - 55" Class X75K 4K HDR LED Google TV | Status : COMPLETED
# Envoi réussi : Samsung - 55" Class Q80C QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 75" Class The Frame QLED 4k Smart Tizen TV - Charcoal Black and 3.1.2ch Soundbar with Wireless Dolby Atmos / DTS:X - Black | Status : COMPLETED
# Envoi réussi : Package - Sony - 75" Class BRAVIA XR Z9J LED 8K UHD Smart Google TV and Ultra Slim Wall Mount for Select SONY TVs - Black | Status : COMPLETED
# Envoi réussi : Samsung - 85" Class QN90B Neo QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - 50" Class UQ75 Series LED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Sony - 85" Class BRAVIA XR X95K 4K HDR Mini LED Google TV | Status : COMPLETED
# Envoi réussi : Samsung - 77" Class S90C OLED Smart Tizen TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Sony - 65" Class BRAVIA XR A90J Series OLED 4K UHD Smart Google TV and Ultra Slim Wall Mount for Select SONY TVs - Black | Status : COMPLETED
# Envoi réussi : Samsung - 55" QMB series LED 4K UHD Digital Signage Display | Status : COMPLETED
# Envoi réussi : Package - Samsung - 65" Class The Serif QLED 4K Smart TV - White and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : LG - 65" Class 90 Series QNED Mini-LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 48" Class BRAVIA XR A90K 4K HDR OLED Google TV and HTA3000 3.1 ch Dolby Atmos Soundbar - Black | Status : USER_ERROR
# Envoi réussi : VIZIO - 50" Class V-Series 4K LED HDR Smart TV | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class S90C OLED Smart Tizen TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : LG - 77" Class C3 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Sony - 55" class X77L 4K HDR LED Google TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 75" Class Q70C QLED 4K SMART TV - Black and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : TCL - 50" Class 4-Series 4K UHD HDR Smart Roku TV | Status : FAILED_CHECKOUT
# Envoi réussi : Package - Samsung - 85" Class QN800C Neo QLED 8K Smart Tizen TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Package - Sony - 65" Class BRAVIA XR A80K OLED 4K UHD HDR Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : Sony - 85" Class BRAVIA XR Z9K 8K HDR Mini LED Google TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 65" Class BRAVIA XR A80K OLED 4K UHD HDR Google TV and HTA3000 3.1 ch Dolby Atmos Soundbar - Black | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - LG - 55" Class C3 Series OLED 4K UHD Smart webOS TV - Dark Titan Silver and 3.1.3 Channel Soundbar C with Wireless Subwoofer, Dolby Atmos, DTS:X & IMAX Enhanced - Black | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Toshiba - 43" Class C350 Series LED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class The Frame Series LED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - Flex 42" Class OLED 4K UHD Smart webOS TV with Bendable Design | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - Roku - 65" Class Plus Series QLED 4K Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : COMPLETED
# Envoi réussi : Hisense - 85" Class A7 Series LED 4K UHD  Google TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Toshiba - 75" Class M550 Series LED 4K UHD Smart Fire TV with hands-free Alexa | Status : COMPLETED
# Envoi réussi : LG - 83" Class C1 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 50" Class 80 Series QNED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 85" Class X85K 4K HDR LED Google TV and Sony HT-A5000 Dolby Atmos Smart Soundbar works with Alexa and Google Assistant, Chromecast built-in, AirPlay2, Bluetooth - Black | Status : COMPLETED
# Envoi réussi : TCL - 58" Class 4-Series 4K UHD HDR Smart Roku TV | Status : COMPLETED
# Envoi réussi : Sony - 55" Class X75K 4K HDR LED Google TV | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class TU690T Series LED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 65" Class F50 Series QLED 4K UHD Smart Fire TV | Status : USER_ERROR
# Envoi réussi : LG - 55" Class B3 Series OLED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Sony - 65" class BRAVIA XR A80L OLED 4K HDR Google TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Samsung - 32" Class M4500 Series LED HD Smart Tizen TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - LG - 86" Class NanoCell 90 Series LED 4K UHD Smart webOS TV - Light Steel Silver and 5.1 Channel High-Res Audio Soundbar with DTS Virtual:X - Black | Status : USER_ERROR
# Envoi réussi : Package - Samsung - 65" Class S90C OLED Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Samsung - 55" QBB series LED 4K UHD Digital Signage Display - Black | Status : COMPLETED
# Envoi réussi : Sony - 65" Class A8H Series OLED 4K UHD Smart Android TV | Status : COMPLETED
# Envoi réussi : Roku - 50" Class Select Series 4K Smart RokuTV | Status : COMPLETED
# Envoi réussi : Package - Roku - 43" Class Select Series 4K Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : INSUFICCIENT_FUNDS
# Envoi réussi : VIZIO - 50" Class V-Series LED 4K UHD Smart TV | Status : COMPLETED
# Envoi réussi : LG - 65" Class C3 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Sony - 65" class X77L 4K HDR LED Google TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - Sony - 83" class BRAVIA XR A80L OLED 4K HDR Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : FRAUD
# Envoi réussi : Samsung - 50" QBB series LED 4K UHD Digital Signage Display | Status : COMPLETED
# Envoi réussi : LG - 65" Class 80 Series QNED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - The Terrace Series 75" Class LED Outdoor Partial Sun 4K UHD Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - The Terrace Series 65" Class LED Outdoor Partial Sun 4K UHD Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Insignia™ - 32" Class F20 Series LED HD Smart Fire TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Samsung - 85" Class QN800C Neo QLED 8K Smart Tizen TV | Status : FRAUD
# Envoi réussi : Insignia™ - 32" Class F20 Series LED Full HD Smart Fire TV | Status : USER_ERROR
# Envoi réussi : Samsung - 65" QBB series LED 4K UHD Digital Signage Display | Status : COMPLETED
# Envoi réussi : Insignia™ - 32" Class N10 Series LED HD TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Toshiba - 55" Class C350 Series LED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 77" Class BRAVIA XR A80K 4K HDR OLED Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : TCL - 50" Class 5-Series 4K UHD QLED Dolby Vision HDR Smart Roku TV | Status : COMPLETED
# Envoi réussi : LG - 55" Class B2 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 50" Class QN90C NEO QLED 4K Smart TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : FAILED_CHECKOUT
# Envoi réussi : Samsung - 75" Class QN84A Neo QLED 4K UHD Smart Tizen TV | Status : FRAUD
# Envoi réussi : LG - 65" Class B2 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : VIZIO - 55" Class MQ6 Series 4K QLED HDR Smart TV | Status : COMPLETED
# Envoi réussi : Package - Roku - 75" Class Select Series 4K Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : COMPLETED
# Envoi réussi : Amazon - 50" Class 4-Series 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Samsung - 75" QBB series LED 4K UHD Digital Signage Display | Status : COMPLETED
# Envoi réussi : Sony - 48" Class BRAVIA XR A90K 4K HDR OLED Google TV | Status : COMPLETED
# Envoi réussi : Samsung - 50" Class Q80C QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - 43" UR640S Series LED 4K UHD Digital Signage TV | Status : FAILED_CHECKOUT
# Envoi réussi : Samsung - 75" Class 7 Series LED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 65" Class F30 Series LED 4K UHD Smart Fire TV | Status : FAILED_API_RESPONSE
# Envoi réussi : LG - 65" Class 83 Series QNED Mini-LED 4K UHD Smart webOS TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - Roku - 65" Class Plus Series QLED 4K Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class QN85B Neo QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : TCL - 75" Class 6-Series 4K UHD Mini-LED QLED Dolby Vision HDR Roku Smart TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - Sony - 42" Class BRAVIA XR A90K 4K HDR OLED Google TV and HTA3000 3.1 ch Dolby Atmos Soundbar - Black | Status : COMPLETED
# Envoi réussi : LG - 55" Class G3 Series OLED 4K UHD Smart webOS TV with One Wall Design | Status : COMPLETED
# Envoi réussi : LG - 55" Class B3 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - The Terrace Series 75" Class LED Outdoor Partial Sun 4K UHD Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Package - Sony - 77" class BRAVIA XR A80L OLED 4K HDR Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : LG - 43" Class UQ75 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 75" class X77L 4K HDR LED Google TV and HTA3000 3.1 ch Dolby Atmos Soundbar - Black | Status : COMPLETED
# Envoi réussi : VIZIO - 40" Class D-Series LED 1080P Smart TV | Status : FAILED_API_RESPONSE
# Envoi réussi : VIZIO - 50" Class V-Series LED 4K UHD Smart TV | Status : COMPLETED
# Envoi réussi : LG - Flex 42" Class OLED 4K UHD Smart webOS TV with Bendable Design | Status : COMPLETED
# Envoi réussi : TCL - 32" Class 3-Series Full HD LED Smart Roku TV | Status : COMPLETED
# Envoi réussi : Samsung - 50" QMB series LED 4K UHD Digital Signage Display | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Sony - 77" Class BRAVIA XR A80K 4K HDR OLED Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : LG - 65" Class UR9000 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Sony - 77" class BRAVIA XR A80L OLED 4K HDR Google TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 50" Class F30 Series LED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Samsung - 60" Class TU690T Series LED 4K UHD Smart Tizen TV | Status : FRAUD
# Envoi réussi : Package - Sony - 75" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : FAILED_API_RESPONSE
# Envoi réussi : Sony - 55" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Sony - 75" Class BRAVIA XR Z9J LED 8K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : Samsung - 55" Class QN90A Neo QLED 4K UHD Smart Tizen TV | Status : FAILED_API_RESPONSE
# Envoi réussi : LG - 55" Class B2 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Roku - 43" Class Select Series 4K Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : COMPLETED
# Envoi réussi : Package - Sony - 55" Class BRAVIA XR A90J Series OLED 4K UHD Smart Google TV and Ultra Slim Wall Mount for Select SONY TVs - Black | Status : FAILED_API_RESPONSE
# Envoi réussi : Samsung - 75" Class Q80B QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Samsung - 60" Class 7 Series LED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Toshiba - 55" Class C350 Series LED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class 6 Series LED 4K UHD Smart Tizen TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Samsung - 77" Class S90C OLED Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : FAILED_API_RESPONSE
# Envoi réussi : LG - 65" Class C3 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 55" Class B2 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Sony - 75" Class X85K 4K HDR LED Google TV | Status : COMPLETED
# Envoi réussi : Samsung - 85" Class  Q80A Series QLED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Sony - 65" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV | Status : COMPLETED
# Envoi réussi : LG - 88" Class Z2 Series OLED 8K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 65" Class QN800C Neo QLED 8K Smart Tizen TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - 65" Class QN90C NEO QLED 4K Smart TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : LG - Pose 55" Class OLED 4K UHD Smart webOS TV with All-Around Design | Status : COMPLETED
# Envoi réussi : TCL - 75" Class 4-Series LED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : LG - 65" Class 99 Series QNED Mini-LED 8K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 24" Class F20 Series LED HD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 50" Class F30 Series LED 4K UHD Smart Fire TV | Status : FAILED_CHECKOUT
# Envoi réussi : Samsung - 85" Class  Q80A Series QLED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : TCL - 75" Class 4-Series LED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class QN900C Neo QLED 8K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Sony - 75" Class BRAVIA XR Z9J LED 8K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : LG - 65" Class G3 Series OLED 4K UHD Smart webOS TV with One Wall Design | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - LG - 65" Class NanoCell 99 Series LED 8K UHD Smart webOS TV - Silver and 5.1 Channel High-Res Audio Soundbar with DTS Virtual:X - Black | Status : USER_ERROR
# Envoi réussi : LG - 86" Class 99 Series QNED Mini-LED 8K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Sony - 85" Class BRAVIA XR X95J 4K UHD Smart Google TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : TCL - 75" Class 6-Series 4K Mini-LED UHD QLED Dolby Vision HDR Smart Roku TV | Status : COMPLETED
# Envoi réussi : Samsung - 55" QMB series LED 4K UHD Digital Signage Display | Status : FAILED_API_RESPONSE
# Envoi réussi : Insignia™ - 65" Class F30 Series LED 4K UHD Smart Fire TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Insignia™ - 43" Class N10 Series LED Full HD TV | Status : FAILED_CHECKOUT
# Envoi réussi : Insignia™ - 70" Class F30 Series LED 4K UHD Smart Fire TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : LG - 55" Class G3 Series OLED 4K UHD Smart webOS TV with One Wall Design | Status : COMPLETED
# Envoi réussi : Sony - 65" Class BRAVIA XR A95K 4K HDR OLED Google TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : LG - 86" Class 90 Series QNED Mini-LED 4K UHD Smart webOS TV | Status : FRAUD
# Envoi réussi : Package - LG - 65" Class G3 Series OLED 4K UHD Smart webOS TV with One Wall Design - Light Satin Silver and 3.1-Channel 420W Soundbar System with Wireless Subwoofer and Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : LG - 55" Class UQ9000 Series LED 4K UHD Smart webOS TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Samsung - 85" Class Q60C QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 50" Class F30 Series LED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : LG - 50" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 85" class BRAVIA XR X93L Mini LED 4K HDR Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : LG - 43" Class UQ9000 Series LED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Sony - 75" Class BRAVIA XR Z9K 8K HDR Mini LED Google TV | Status : COMPLETED
# Envoi réussi : Toshiba - 43" Class V35 Series LED Full HD Smart Fire TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Insignia™ - 43" Class N10 Series LED Full HD TV - Black and Google - Chromecast with Google TV (HD) - Snow | Status : COMPLETED
# Envoi réussi : Package - Samsung - 65" Class QN800C Neo QLED 8K Smart Tizen TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - 65" Class QN85C NEO QLED 4K Smart Tizen TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : LG - 86" Class NanoCell 90 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 85" Class CU8000 Crystal UHD Smart Tizen TV - Black and SAMSUNG C Series 2.1ch DTS Virtual: X Soundbar - Titan Black | Status : COMPLETED
# Envoi réussi : TCL - 65" Class 5-Series 4K UHD QLED Dolby Vision HDR Smart Roku TV | Status : COMPLETED
# Envoi réussi : Toshiba - 65" Class C350 Series LED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Roku - 75" Class Plus Series QLED 4K Smart RokuTV | Status : COMPLETED
# Envoi réussi : LG - 55" Class UQ75 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Sony - 77" Class BRAVIA XR A80K 4K HDR OLED Google TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - Sony - 85" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : LG - 77" Class G2 Series OLED evo 4K UHD Smart webOS TV with Gallery Design | Status : COMPLETED
# Envoi réussi : Package - Samsung - 55" Class S95C OLED 4K Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Sony - 65" Class A8H Series OLED 4K UHD Smart Android TV | Status : COMPLETED
# Envoi réussi : Hisense - 70" Class A6 Series LED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : Roku - 55" Class Plus Series QLED 4K Smart RokuTV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 75" Class The Frame QLED 4k Smart Tizen TV - Charcoal Black and 3.1.2ch Soundbar with Wireless Dolby Atmos / DTS:X - Black | Status : COMPLETED
# Envoi réussi : Package - Roku - 55" Class Select Series 4K Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : COMPLETED
# Envoi réussi : LG - 65" Class C1 Series OLED 4K UHD Smart webOS TV | Status : USER_ERROR
# Envoi réussi : Sony - 85" Class BRAVIA XR X95K 4K HDR Mini LED Google TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Samsung - 85" Class QN90C NEO QLED 4K Smart TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : INSUFICCIENT_FUNDS
# Envoi réussi : LG - 43" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 83" Class C3 Series OLED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Samsung - 65" Class The Frame Series LED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - 75" Class UP7300PUC LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Sony - 83" class BRAVIA XR A80L OLED 4K HDR Google TV | Status : COMPLETED
# Envoi réussi : Sony - 85" Class BRAVIA XR X95J 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : VIZIO - 75" Class P-Series 4K QLED HDR Smart TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 75" Class X85K 4K HDR LED Google TV and HTA3000 3.1 ch Dolby Atmos Soundbar - Black | Status : COMPLETED
# Envoi réussi : LG - Flex 42" Class OLED 4K UHD Smart webOS TV with Bendable Design | Status : COMPLETED
# Envoi réussi : LG - 83" Class C3 Series OLED 4K UHD Smart webOS TV | Status : USER_ERROR
# Envoi réussi : Package - Insignia™ - 32" Class N10 Series LED HD TV - Black and Google - Chromecast with Google TV (HD) - Snow | Status : USER_ERROR
# Envoi réussi : Sony - 65" class BRAVIA XR A80L OLED 4K HDR Google TV | Status : COMPLETED
# Envoi réussi : Package - LG - 83" Class G3 Series OLED 4K UHD Smart webOS TV with One Wall Design - Light Satin Silver and 3.1-Channel 420W Soundbar System with Wireless Subwoofer and Dolby Atmos - Black | Status : USER_ERROR
# Envoi réussi : Samsung - 43" CLASS BE43T-H LED 4K Commercial Grade TV | Status : FAILED_CHECKOUT
# Envoi réussi : LG - 77" Class A2 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Sharp - 65" Class LED 4K Smart Roku TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Samsung - 77" Class S90C OLED Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Sony - 55" Class BRAVIA XR A95K 4K HDR OLED Google TV | Status : COMPLETED
# Envoi réussi : Toshiba - 75" Class M550 Series LED 4K UHD Smart Fire TV with hands-free Alexa | Status : COMPLETED
# Envoi réussi : Samsung - 70" Class Q60C QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : TCL - 50" Class 4-Series 4K UHD HDR Smart Roku TV | Status : COMPLETED
# Envoi réussi : Sony - 75" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : TCL - 65" Class 5-Series 4K UHD QLED Dolby Vision HDR Smart Roku TV | Status : COMPLETED
# Envoi réussi : LG - Pose 55" Class OLED 4K UHD Smart webOS TV with All-Around Design | Status : COMPLETED
# Envoi réussi : Hisense - 40" Class A4 Series LED Full HD Smart Android TV | Status : COMPLETED
# Envoi réussi : Samsung - 65" CLASS BE65T-H LED 4K Commercial Grade TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : LG - 65" Class UQ75 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 43" UR340C Series LED 4K UHD Digital Signage TV | Status : USER_ERROR
# Envoi réussi : Package - Samsung - 75" Class QN90C NEO QLED 4K Smart TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : VIZIO - 43" Class MQ6 Series 4K QLED HDR Smart TV | Status : COMPLETED
# Envoi réussi : LG - 48" Class A2 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : TCL - 75" Class 5-Series QLED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 58" Class F30 Series LED 4K UHD Smart Fire TV | Status : USER_ERROR
# Envoi réussi : LG - 43" Class 75 Series QNED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Samsung - 85" Class QN900C Neo QLED 8K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class QN90A Neo QLED 4K UHD Smart Tizen TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Samsung - 75" Class QN800C Neo QLED 8K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 32" Class F20 Series LED Full HD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class QN900C Neo QLED 8K Smart Tizen TV | Status : COMPLETED
# ...
# Envoi réussi : LG - 77" Class C2 Series OLED evo 4K  UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Samsung - 55" Class S95B OLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Hisense - 50" Class R6G Series LED 4K UHD Smart Roku TV | Status : COMPLETED
# Envoi réussi : Package - LG - 83" Class G3 Series OLED 4K UHD Smart webOS TV with One Wall Design - Light Satin Silver and 3.1-Channel 420W Soundbar System with Wireless Subwoofer and Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - The Terrace Series 75" Class LED Outdoor Partial Sun 4K UHD Smart Tizen TV and 3.0-Channel The Terrace Soundbar with Dolby Digital 5.1 - Titan Black | Status : COMPLETED
# Envoi réussi : LG - 97" Class G2 Series OLED evo 4K UHD Smart webOS TV with Gallery Design | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class QN85B Neo QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 77" class BRAVIA XR A80L OLED 4K HDR Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : USER_ERROR
# Envoi réussi : Package - Samsung - 85" Class Q60C QLED 4K Smart Tizen TV - TITAN GRAY and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Samsung - 50" Class Q60C QLED 4K Smart Tizen TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Sony - 85" class BRAVIA XR X93L Mini LED 4K HDR Google TV | Status : COMPLETED
# Envoi réussi : Sony - 55" Class BRAVIA XR A90J Series OLED 4K UHD Smart Google TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : LG - 65" Class UR9000 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 86" Class 99 Series QNED Mini-LED 8K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - StanbyME 27" Class LED Full HD Smart webOS Touch Screen | Status : COMPLETED
# Envoi réussi : Package - Roku - 40" Class Select Series Full HD Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class S90C OLED Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 77" Class S95C OLED 4K Smart Tizen TV - TITAN BLACK and SAMSUNG Q-Series 3.1ch Dolby Atmos Soundbar w/Q-Symphony. - Titan Black | Status : COMPLETED
# Envoi réussi : Hisense - 50" Class A6 Series LED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 65" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV and Sony HT-A5000 Dolby Atmos Smart Soundbar works with Alexa and Google Assistant, Chromecast built-in, AirPlay2, Bluetooth - Black | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class Q80B QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - 55" Class C3 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : VIZIO - 40" Class D-Series Full HD Smart TV | Status : COMPLETED
# Envoi réussi : Amazon - 55" Class Omni Series 4K UHD Smart Fire TV hands-free with Alexa | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Sony - 48" Class BRAVIA XR A90K 4K HDR OLED Google TV | Status : COMPLETED
# Envoi réussi : Samsung - 60" Class Q60B QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Package - LG - 65" Class C3 Series OLED 4K UHD Smart webOS TV - Dark Titan Silver and 3.1.3 Channel Soundbar C with Wireless Subwoofer, Dolby Atmos, DTS:X & IMAX Enhanced - Black | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class QN90A Neo QLED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : TCL - 32" Class 3-Series FHD 1080p LED Smart Google TV | Status : COMPLETED
# Envoi réussi : Samsung - 58" Class 7 Series LED 4K UHD Smart Tizen TV | Status : FAILED_API_RESPONSE
# Envoi réussi : LG - 50" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : TCL - 55" Class 6-Series Mini-LED QLED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : Peerless-AV - 55" Neptune™ Partial Sun 4K HDR Outdoor Smart TV – Comes with FREE Outdoor Tilting Wall Mount | Status : COMPLETED
# Envoi réussi : Sony - 55" class X77L 4K HDR LED Google TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 65" Class Q80C QLED 4K Smart Tizen TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Samsung - 55" Class S95C OLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class QN800C Neo QLED 8K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : VIZIO - 43" Class MQ6 Series 4K QLED HDR Smart TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 43" Class N10 Series LED Full HD TV | Status : COMPLETED
# Envoi réussi : LG - 77" Class B2 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Sony - 85" Class BRAVIA XR X95K 4K HDR Mini LED Google TV | Status : COMPLETED
# Envoi réussi : VIZIO - 50" Class V-Series 4K LED HDR Smart TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 85" Class CU8000 Crystal UHD Smart Tizen TV - Black and SAMSUNG C Series 2.1ch DTS Virtual: X Soundbar - Titan Black | Status : COMPLETED
# Envoi réussi : Samsung - 75" Class QN800 Neo QLED 8K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 24" Class F20 Series LED Full HD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 75" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : FAILED_CHECKOUT
# Envoi réussi : Amazon - 55" Class Omni QLED Series 4K UHD smart Fire TV | Status : USER_ERROR
# Envoi réussi : Insignia™ - 43" Class F30 Series LED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Sony - 75" class BRAVIA XR X93L Mini LED 4K HDR Google TV | Status : COMPLETED
# Envoi réussi : LG - 65" Class A2 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - LG - 65" Class C2 Series OLED evo 4K  UHD Smart webOS TV - Dark Silver and 5.1.3 Channel Soundbar with Wireless Subwoofer, Dolby Atmos and DTS:X - Black | Status : COMPLETED
# Envoi réussi : LG - 83" Class C1 Series OLED 4K UHD Smart webOS TV | Status : USER_ERROR
# Envoi réussi : Samsung - 55" Class Q60B QLED 4K Smart Tizen TV | Status : USER_ERROR
# Envoi réussi : Samsung - 55" Class 8000 Series LED 4K UHD Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Toshiba - 55" Class C350 Series LED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Samsung - 50" Class Q80B QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Sony - 65" Class X85K 4K HDR LED Google TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 32" Class F20 Series LED Full HD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 75" Class Q70C QLED 4K SMART TV - Black and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - 85" Class CU8000 Crystal UHD Smart Tizen TV - Black and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Sony - 48" Class BRAVIA A9S Series OLED 4K UHD Smart Android TV | Status : COMPLETED
# Envoi réussi : LG - 55" Class 85 Series QNED Mini-LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 77" Class C3 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Samsung - 70" Class Q60C QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - The Terrace Series 75" Class LED Outdoor Full Sun 4K QLED Smart Tizen TV and 3.0-Channel The Terrace Soundbar with Dolby Digital 5.1 - Titan Black | Status : COMPLETED
# Envoi réussi : Package - Samsung - 65" Class The Frame QLED 4k Smart Tizen TV - Charcoal Black and 3.1.2ch Soundbar with Wireless Dolby Atmos / DTS:X - White | Status : FAILED_CHECKOUT
# Envoi réussi : Samsung - 75" Class QN900B Neo QLED 8K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - 50" Class 80 Series QNED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 85" Class CU8000 Crystal UHD Smart Tizen TV - Black and SAMSUNG C Series 2.1ch DTS Virtual: X Soundbar - Titan Black | Status : COMPLETED
# Envoi réussi : Samsung - 50" Class Q60B QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : LG - 77" Class A2 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 75" Class 80 Series QNED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - The Terrace Series 75" Class LED Outdoor Partial Sun 4K UHD Smart Tizen TV and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Sony - 65" Class BRAVIA XR A95K 4K HDR OLED Google TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 65" Class F50 Series QLED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Insignia™ - 32" Class F20 Series LED Full HD Smart Fire TV | Status : FAILED_CHECKOUT
# Envoi réussi : Samsung - 85" Class QN90B Neo QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Amazon - 43" Class Omni QLED Series 4K UHD smart Fire TV | Status : COMPLETED
# Envoi réussi : Samsung - 85" Class Q60C QLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : TCL - 65" Class 5-Series 4K UHD QLED Dolby Vision HDR Smart Roku TV | Status : FRAUD
# Envoi réussi : Package - Sony - 83" class BRAVIA XR A80L OLED 4K HDR Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : Sony - 55" class BRAVIA XR A80L OLED 4K HDR Google TV | Status : COMPLETED
# Envoi réussi : LG - 75" Class 75 Series QNED 4K UHD Smart webOS TV | Status : FAILED_CHECKOUT
# Envoi réussi : Package - Samsung - 65" Class Q70C QLED 4K SMART TV - Black and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : LG - 83" Class C3 Series OLED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Roku - 55" Class Plus Series QLED 4K Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : COMPLETED
# Envoi réussi : VIZIO - 75" Class V-Series LED 4K UHD Smart TV | Status : COMPLETED
# Envoi réussi : VIZIO - 50" Class V-Series LED 4K UHD Smart TV | Status : COMPLETED
# Envoi réussi : LG - 77" Class Z2 Series OLED 8K UHD Smart webOS TV with Gallery Design | Status : COMPLETED
# Envoi réussi : LG - 65" Class UQ9000 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Samsung - 85" Class Q80B QLED 4K Smart Tizen TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Sony - 75" Class X80K Series LED 4K HDR Smart Google TV | Status : FAILED_API_RESPONSE
# Envoi réussi : TCL - 55" Class 6-Series Mini-LED QLED 4K UHD Smart Google TV | Status : FAILED_CHECKOUT
# Envoi réussi : Sony - 75" Class X85K 4K HDR LED Google TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - Sony - 65" Class X80K Series LED 4K UHD HDR Smart Google TV and Sony HT-A5000 Dolby Atmos Smart Soundbar works with Alexa and Google Assistant, Chromecast built-in, AirPlay2, Bluetooth - Black | Status : COMPLETED
# Envoi réussi : Sony - 85" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV | Status : COMPLETED
# Envoi réussi : Hisense - 40" Class A4 Series LED Full HD Smart Android TV | Status : COMPLETED
# Envoi réussi : LG - 55" Class UQ9000 Series LED 4K UHD Smart webOS TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - Sony - 75" Class X85K 4K HDR LED Google TV and HTA3000 3.1 ch Dolby Atmos Soundbar - Black | Status : COMPLETED
# Envoi réussi : Hisense - 43" Class R6G Series LED 4K UHD Smart Roku TV | Status : COMPLETED
# Envoi réussi : Package - Insignia™ - 32" Class N10 Series LED HD TV - Black and Google - Chromecast with Google TV (HD) - Snow | Status : COMPLETED
# Envoi réussi : VIZIO - 75" Class P-Series 4K QLED HDR Smart TV | Status : COMPLETED
# Envoi réussi : Samsung - 70" Class  Q60A Series QLED 4K UHD Smart Tizen TV | Status : FAILED_API_RESPONSE
# Envoi réussi : LG - 77" Class Z2 Series OLED 8K UHD Smart webOS TV with Gallery Design | Status : COMPLETED
# Envoi réussi : LG - 43" Class UQ9000 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 85" Class Q80C QLED 4K Smart Tizen TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : Insignia™ - 65" Class F30 Series LED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : VIZIO - 75" Class V-Series 4K LED HDR Smart TV | Status : COMPLETED
# Envoi réussi : Package - Sony - 75" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV and HT-A7000 7.1.2 Channel Soundbar with Dolby Atmos - Black | Status : COMPLETED
# Envoi réussi : Sony - 65" class BRAVIA XR A80L OLED 4K HDR Google TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : Package - Samsung - 55" Class QN85C NEO QLED 4K Smart Tizen TV - TITAN BLACK and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : COMPLETED
# Envoi réussi : LG - 43" UR340C Series LED 4K UHD Digital Signage TV | Status : FAILED_API_RESPONSE
# Envoi réussi : LG - 43" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 75" Class 85 Series QNED Mini-LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : LG - 55" Class UQ9000 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Sony - 55" Class BRAVIA XR A80J Series OLED 4K UHD Smart Google TV | Status : USER_ERROR
# Envoi réussi : Amazon - 75" Class Omni QLED Series 4K UHD smart Fire TV | Status : COMPLETED
# Envoi réussi : LG - 55" Class 85 Series QNED Mini-LED 4K UHD Smart webOS TV | Status : FAILED_CHECKOUT
# Envoi réussi : Sony - 50" Class X85K 4K HDR LED Google TV | Status : COMPLETED
# Envoi réussi : Sony - 55" Class BRAVIA XR A90J Series OLED 4K UHD Smart Google TV | Status : COMPLETED
# Envoi réussi : Sony - 85" Class BRAVIA XR Z9K 8K HDR Mini LED Google TV | Status : USER_ERROR
# Envoi réussi : LG - 50" Class 75 Series QNED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - LG - 55" Class C3 Series OLED 4K UHD Smart webOS TV - Dark Titan Silver and 3.1.3 Channel Soundbar C with Wireless Subwoofer, Dolby Atmos, DTS:X & IMAX Enhanced - Black | Status : FAILED_API_RESPONSE
# Envoi réussi : Sony - 75" Class X80K Series LED 4K HDR Smart Google TV | Status : COMPLETED
# Envoi réussi : Package - Samsung - 65" Class The Serif QLED 4K Smart TV - White and Q-Series  9.1.4ch  Wireless True Dolby Atmos Soundbar +  Rear Speakers w/ Q-Symphony - Titan Black | Status : FAILED_API_RESPONSE
# Envoi réussi : Package - Roku - 24" Class Select Series HD Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : USER_ERROR
# Envoi réussi : Samsung - 50" CLASS BE50T-H LED 4K Commercial Grade TV | Status : COMPLETED
# Envoi réussi : Pioneer - 43" Class LED 4K UHD Smart Fire TV | Status : INSUFICCIENT_FUNDS
# Envoi réussi : LG - 50" Class UQ75 Series LED 4K UHD Smart webOS TV | Status : COMPLETED
# Envoi réussi : Package - Roku - 55" Class Plus Series QLED 4K Smart RokuTV and 2.0-Channel Wireless Soundbar 2023 Exclusively for RokuTV - Black | Status : FAILED_CHECKOUT
# Envoi réussi : LG - 55" Class G3 Series OLED 4K UHD Smart webOS TV with One Wall Design | Status : FAILED_CHECKOUT
# Envoi réussi : Insignia™ - 32" Class F20 Series LED  HD Smart Fire TV | Status : FAILED_API_RESPONSE
# Envoi réussi : Insignia™ - 70" Class F50 Series QLED 4K UHD Smart Fire TV | Status : COMPLETED
# Envoi réussi : Samsung - 65" Class S95B OLED 4K Smart Tizen TV | Status : COMPLETED
# Envoi réussi : Samsung - 50" QMB series LED 4K UHD Digital Signage Display | Status : COMPLETED
# Envoi réussi : LG - 65" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV | Status : COMPLETED
